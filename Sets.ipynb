# %% [markdown]
# **Sets - Collection of unordered objects**

# %%
ds = {"Dipen", "Prerak", "Niket"}

# %% [markdown]
# **1. add() - add the element to the set**

# %%
ds.add("Mirant")
ds
# Out:
# {'Dipen', 'Mirant', 'Niket', 'Prerak'}

# %% [markdown]
# **2. copy() - returns the copy of set**

# %%
ds1 = ds.copy()
ds1
# Out:
# {'Dipen', 'Mirant', 'Niket', 'Prerak'}

# %% [markdown]
# **3. clear() - removes all the elements from the set**

# %%
ds1.clear()
ds1
# Out:
# set()

# %% [markdown]
# **4.difference() - returns the difference between two or more sets.**

# %%
ds1 = ds.copy()
ds1.add("Appu")

ds1.difference(ds)
# Out:
# {'Appu'}

# %% [markdown]
# **5. difference_update() - delete all same objects, it only keeps different objects in set.**

# %%
ds1.difference_update(ds)
ds1
# Out:
# {'Appu'}

# %% [markdown]
# **6. discard() - Removes the specified item, if item doesn't exist then it doesn't raise an error**

# %%
ds.discard("Niket")
ds
# Out:
# {'Dipen', 'Mirant', 'Prerak'}

# %% [markdown]
# **7. intersection() - It is used to see the same set of objects between two sets.**

# %%
ds1.add("Prerak")

ds.intersection(ds1)
# Out:
# {'Prerak'}

# %% [markdown]
# **8. intersection_update() - keeps all same objects in set and it deletes all different objects.**

# %%
ds1.intersection_update(ds)
ds1
# Out:
# {'Prerak'}

# %% [markdown]
# **9. isdisjoint() - Returns whether two sets have a intersection or not.**

# %%
ds.isdisjoint(ds1)
# Out:
# False

# %% [markdown]
# **10. issubset() - returns whether all objects of this set is present in another set.**

# %%
ds1.issubset(ds)
# Out:
# True

# %% [markdown]
# **11. issuperset() - Returns whether this set contains another set or not.**

# %%
ds.issuperset(ds1)
# Out:
# True

# %%
ds.add("Dhrumi")
ds
# Out:
# {'Dhrumi', 'Dipen', 'Mirant', 'Prerak'}

# %% [markdown]
# **12. pop() - removes the object from set(Random)**

# %%
ds.pop()
# Out:
# 'Mirant'

# %% [markdown]
# **13. remove() - removes the specific element from set**

# %%
ds.add("Dev")

ds.remove("Prerak")

# %%
ds
# Out:
# {'Dev', 'Dhrumi', 'Dipen'}

# %% [markdown]
# **14. symmetric_difference() - Return a set that contains all items from both sets, except items that are present in both sets**

# %%
ds.symmetric_difference(ds1)
# Out:
# {'Dev', 'Dhrumi', 'Dipen', 'Prerak'}

# %%
ds1.add("Dev")
ds1, ds
# Out:
# ({'Dev', 'Prerak'}, {'Dev', 'Dhrumi', 'Dipen'})

# %% [markdown]
# **15. symmetric_difference_update() - inserts the symmetric differences from this set and another**

# %%
ds.symmetric_difference_update(ds1)
ds
# Out:
# {'Dhrumi', 'Dipen', 'Prerak'}

# %%
ds.add(12)
ds
# Out:
# {12, 45, 'Dhrumi', 'Dipen', 'Prerak'}

# %% [markdown]
# **16. union() - Returns a set containing the union of sets.**

# %%
ds.union(ds1)
# Out:
# {12, 45, 'Dev', 'Dhrumi', 'Dipen', 'Prerak'}

# %%
ds
# Out:
# {12, 45, 'Dhrumi', 'Dipen', 'Prerak'}

# %% [markdown]
# **17. update() - insert the items of second set to first set**

# %%
ds.update(ds1)
ds
# Out:
# {12, 45, 'Dev', 'Dhrumi', 'Dipen', 'Prerak'}
